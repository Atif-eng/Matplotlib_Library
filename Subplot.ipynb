# %% [markdown]
# # Subplot

# %%
from matplotlib import pyplot as plt
x=[1,2,3,4,5,6]
y=[1,3,2,5,4,6]

plt.subplot(2,2,1)
plt.plot(x,y)

plt.subplot(2,2,2)
plt.bar(x,y)

plt.subplot(2,2,3)
plt.pie(y,labels=x,autopct='%0.1f%%',textprops={'fontsize':7})

plt.subplot(2,2,4)
plt.stem(y,x)

plt.show()
